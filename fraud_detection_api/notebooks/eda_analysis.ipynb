# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-kkb-ass1a0-2epv0jg2erd0m-a.asia-southeast1-0.prod.colab.dev/'. Verify the server is running and reachable. (Kernel not initialized in Session).
